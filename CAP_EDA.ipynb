# %% [markdown]
# <a href="https://colab.research.google.com/github/ShresthiS24/Traffic-flow-Repo/blob/main/CAP_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-741beb12-b8ef-416c-a3e8-1eee1150af58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-741beb12-b8ef-416c-a3e8-1eee1150af58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
# read datasdet using pandas
df = pd.read_csv('/content/chicago-traffic-tracker.csv')
df.head()
# Out:
#                      TIME  SEGMENT_ID  SPEED  STREET DIRECTION  \
# 0  03/21/2018 05:31:29 PM        1133     23  Cicero        SB
# 1  03/21/2018 05:31:29 PM        1134     20  Cicero        SB
# 2  03/21/2018 05:31:29 PM        1151     20  Harlem        NB
# 3  03/21/2018 05:31:29 PM        1152     23  Harlem        NB
# 4  03/21/2018 05:31:29 PM        1153     14  Harlem        NB
#
#            FROM_STREET  TO_STREET  LENGTH STREET_HEADING             COMMENTS  \
# 0               Cermak       31st    1.00              S  Outside City Limits
# 1            Roosevelt     Cermak    1.02              S  Outside City Limits
# 2              Madison    Chicago    1.01              S  Outside City Limits
# 3              Chicago  North Ave    1.01              N  Outside City Limits
# 4  Forest Preserve Ave   Gunnison    1.00              N  Outside City Limits
#
#    ...          RECORD_ID  START_LATITUDE  START_LONGITUDE  END_LATITUDE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 25 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   TIME             1048575 non-null  object
#  1   SEGMENT_ID       1048575 non-null  int64
#  2   SPEED            1048575 non-null  int64
#  3   STREET           1048575 non-null  object
#  4   DIRECTION        1048575 non-null  object
#  5   FROM_STREET      1048575 non-null  object
#  6   TO_STREET        1048575 non-null  object
#  7   LENGTH           1048575 non-null  float64
#  8   STREET_HEADING   1048575 non-null  object
#  9   COMMENTS         127185 non-null   object
#  10  BUS_COUNT        1048575 non-null  int64
#  11  MESSAGE_COUNT    1048575 non-null  int64
#  12  HOUR             1048575 non-null  int64
#  13  DAY_OF_WEEK      1048575 non-null  int64
#  14  MONTH            1048575 non-null  int64
#  15  RECORD_ID        1048575 non-null  object
# ...

# %%
df.shape
# Out:
# (1048575, 25)

# %%
df.isnull().sum()
# Out:
# TIME                   0
# SEGMENT_ID             0
# SPEED                  0
# STREET                 0
# DIRECTION              0
# FROM_STREET            0
# TO_STREET              0
# LENGTH                 0
# STREET_HEADING         0
# BUS_COUNT              0
# MESSAGE_COUNT          0
# HOUR                   0
# DAY_OF_WEEK            0
# MONTH                  0
# RECORD_ID              0
# START_LATITUDE         0
# START_LONGITUDE        0
# END_LATITUDE           0
# END_LONGITUDE          0
# START_LOCATION         0
# END_LOCATION           0
# Community Areas    65101
# Zip Codes              0
# Wards              65101
# dtype: int64

# %%
df = df.drop(columns=['COMMENTS'])
